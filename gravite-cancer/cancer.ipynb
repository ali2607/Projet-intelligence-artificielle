# %%
# Imports
import os, warnings
import matplotlib.pyplot as plt
from matplotlib import gridspec

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Load training and validation sets
ds_train_ = image_dataset_from_directory(
    '../input/skin-cancer-malignant-vs-benign/train',
    labels='inferred',
    label_mode='binary',
    image_size=[224, 244],
    interpolation='nearest',
    batch_size=64,
    shuffle=True,
)
ds_valid_ = image_dataset_from_directory(
    '../input/skin-cancer-malignant-vs-benign/test',
    labels='inferred',
    label_mode='binary',
    image_size=[224, 244],
    interpolation='nearest',
    batch_size=64,
    shuffle=False,
)

# Data Pipeline
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE
ds_train = (
    ds_train_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
ds_valid = (
    ds_valid_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
# Out:
# Found 2637 files belonging to 2 classes.
# Found 660 files belonging to 2 classes.

# %%
from tensorflow.python.keras.applications.vgg16 import VGG16
pretrained_base =VGG16(include_top=False, weights=None, input_tensor=None,
           input_shape=(224,244,3))
pretrained_base.load_weights('../input/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5')
pretrained_base.trainable = False

# %%
from tensorflow import keras
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping

model=keras.Sequential([
    layers.InputLayer(input_shape=[224, 244, 3]),
    #augmentation
    preprocessing.RandomFlip('horizontal'),
    preprocessing.RandomFlip('vertical'),
    #preprocessing.RandomRotation(factor=0.2),
    #base
    pretrained_base,
    #head
    layers.Flatten(),
    layers.Dense(1024,activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(1024,activation='relu'),
    layers.Dropout(0.3),
    #layers.Dense(1024,activation='relu'),
    #layers.Dropout(0.3),
    layers.Dense(1,activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)
early = EarlyStopping(min_delta=0.001, patience=20, restore_best_weights=True,)


history=model.fit(
    ds_train,
    validation_data=ds_valid,
    callbacks=[early],
    epochs=500,
)
# Out:
# Epoch 1/500
# 42/42 [==============================] - 8s 173ms/step - loss: 1.7622 - binary_accuracy: 0.5976 - val_loss: 0.4377 - val_binary_accuracy: 0.7833
# Epoch 2/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.4161 - binary_accuracy: 0.8176 - val_loss: 0.4553 - val_binary_accuracy: 0.7727
# Epoch 3/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.3889 - binary_accuracy: 0.8185 - val_loss: 0.4049 - val_binary_accuracy: 0.8106
# Epoch 4/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.3537 - binary_accuracy: 0.8437 - val_loss: 0.3898 - val_binary_accuracy: 0.8136
# Epoch 5/500
# 42/42 [==============================] - 7s 169ms/step - loss: 0.3433 - binary_accuracy: 0.8418 - val_loss: 0.4007 - val_binary_accuracy: 0.8121
# Epoch 6/500
# 42/42 [==============================] - 7s 168ms/step - loss: 0.3473 - binary_accuracy: 0.8362 - val_loss: 0.4366 - val_binary_accuracy: 0.7985
# Epoch 7/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.3437 - binary_accuracy: 0.8400 - val_loss: 0.4910 - val_binary_accuracy: 0.7621
# Epoch 8/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.3453 - binary_accuracy: 0.8340 - val_loss: 0.3606 - val_binary_accuracy: 0.8318
# Epoch 9/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.3181 - binary_accuracy: 0.8585 - val_loss: 0.3360 - val_binary_accuracy: 0.8394
# Epoch 10/500
# 42/42 [==============================] - 7s 169ms/step - loss: 0.3017 - binary_accuracy: 0.8541 - val_loss: 0.4139 - val_binary_accuracy: 0.8030
# Epoch 11/500
# 42/42 [==============================] - 7s 168ms/step - loss: 0.3164 - binary_accuracy: 0.8451 - val_loss: 0.4423 - val_binary_accuracy: 0.7955
# Epoch 12/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.3304 - binary_accuracy: 0.8395 - val_loss: 0.3481 - val_binary_accuracy: 0.8318
# Epoch 13/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.3265 - binary_accuracy: 0.8407 - val_loss: 0.4655 - val_binary_accuracy: 0.7924
# Epoch 14/500
# 42/42 [==============================] - 7s 168ms/step - loss: 0.3450 - binary_accuracy: 0.8283 - val_loss: 0.3390 - val_binary_accuracy: 0.8379
# Epoch 15/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.3193 - binary_accuracy: 0.8483 - val_loss: 0.3276 - val_binary_accuracy: 0.8515
# Epoch 16/500
# 42/42 [==============================] - 7s 168ms/step - loss: 0.2986 - binary_accuracy: 0.8581 - val_loss: 0.3334 - val_binary_accuracy: 0.8439
# Epoch 17/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.2892 - binary_accuracy: 0.8652 - val_loss: 0.3311 - val_binary_accuracy: 0.8470
# Epoch 18/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.2812 - binary_accuracy: 0.8607 - val_loss: 0.4570 - val_binary_accuracy: 0.7864
# Epoch 19/500
# 42/42 [==============================] - 7s 168ms/step - loss: 0.3022 - binary_accuracy: 0.8517 - val_loss: 0.3369 - val_binary_accuracy: 0.8394
# Epoch 20/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.3014 - binary_accuracy: 0.8324 - val_loss: 0.3283 - val_binary_accuracy: 0.8379
# Epoch 21/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.2618 - binary_accuracy: 0.8735 - val_loss: 0.3556 - val_binary_accuracy: 0.8121
# Epoch 22/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.2843 - binary_accuracy: 0.8694 - val_loss: 0.3280 - val_binary_accuracy: 0.8576
# Epoch 23/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.2723 - binary_accuracy: 0.8601 - val_loss: 0.3421 - val_binary_accuracy: 0.8455
# Epoch 24/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.2975 - binary_accuracy: 0.8519 - val_loss: 0.3570 - val_binary_accuracy: 0.8333
# Epoch 25/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.2743 - binary_accuracy: 0.8781 - val_loss: 0.3440 - val_binary_accuracy: 0.8470
# Epoch 26/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.3182 - binary_accuracy: 0.8483 - val_loss: 0.3341 - val_binary_accuracy: 0.8364
# Epoch 27/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.2733 - binary_accuracy: 0.8616 - val_loss: 0.3418 - val_binary_accuracy: 0.8500
# Epoch 28/500
# 42/42 [==============================] - 7s 168ms/step - loss: 0.2717 - binary_accuracy: 0.8627 - val_loss: 0.3264 - val_binary_accuracy: 0.8485
# Epoch 29/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.2662 - binary_accuracy: 0.8562 - val_loss: 0.3265 - val_binary_accuracy: 0.8530
# Epoch 30/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.2742 - binary_accuracy: 0.8422 - val_loss: 0.3583 - val_binary_accuracy: 0.8379
# Epoch 31/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.2842 - binary_accuracy: 0.8482 - val_loss: 0.3455 - val_binary_accuracy: 0.8591
# Epoch 32/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.2876 - binary_accuracy: 0.8694 - val_loss: 0.5132 - val_binary_accuracy: 0.7591
# Epoch 33/500
# 42/42 [==============================] - 7s 169ms/step - loss: 0.3444 - binary_accuracy: 0.8322 - val_loss: 0.3407 - val_binary_accuracy: 0.8379
# Epoch 34/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.3227 - binary_accuracy: 0.8213 - val_loss: 0.3561 - val_binary_accuracy: 0.8470
# Epoch 35/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.2801 - binary_accuracy: 0.8419 - val_loss: 0.3315 - val_binary_accuracy: 0.8545
# Epoch 36/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.2738 - binary_accuracy: 0.8575 - val_loss: 0.3279 - val_binary_accuracy: 0.8500
# Epoch 37/500
# 42/42 [==============================] - 7s 168ms/step - loss: 0.2994 - binary_accuracy: 0.8535 - val_loss: 0.3535 - val_binary_accuracy: 0.8545
# Epoch 38/500
# 42/42 [==============================] - 7s 168ms/step - loss: 0.2534 - binary_accuracy: 0.8719 - val_loss: 0.3462 - val_binary_accuracy: 0.8424
# Epoch 39/500
# 42/42 [==============================] - 7s 168ms/step - loss: 0.2538 - binary_accuracy: 0.8834 - val_loss: 0.3613 - val_binary_accuracy: 0.8530
# Epoch 40/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.2581 - binary_accuracy: 0.8614 - val_loss: 0.3579 - val_binary_accuracy: 0.8636
# Epoch 41/500
# 42/42 [==============================] - 7s 168ms/step - loss: 0.2808 - binary_accuracy: 0.8580 - val_loss: 0.3442 - val_binary_accuracy: 0.8652
# Epoch 42/500
# 42/42 [==============================] - 7s 169ms/step - loss: 0.2481 - binary_accuracy: 0.8749 - val_loss: 0.3738 - val_binary_accuracy: 0.8500
# Epoch 43/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.2306 - binary_accuracy: 0.8817 - val_loss: 0.3689 - val_binary_accuracy: 0.8591
# Epoch 44/500
# 42/42 [==============================] - 7s 168ms/step - loss: 0.2519 - binary_accuracy: 0.8718 - val_loss: 0.3434 - val_binary_accuracy: 0.8470
# Epoch 45/500
# 42/42 [==============================] - 7s 168ms/step - loss: 0.2559 - binary_accuracy: 0.8672 - val_loss: 0.3737 - val_binary_accuracy: 0.8545
# Epoch 46/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.2389 - binary_accuracy: 0.8770 - val_loss: 0.3690 - val_binary_accuracy: 0.8500
# Epoch 47/500
# 42/42 [==============================] - 7s 169ms/step - loss: 0.2478 - binary_accuracy: 0.8766 - val_loss: 0.3424 - val_binary_accuracy: 0.8621
# Epoch 48/500
# 42/42 [==============================] - 7s 167ms/step - loss: 0.2394 - binary_accuracy: 0.8707 - val_loss: 0.3842 - val_binary_accuracy: 0.8576

# %%
import pandas as pd

history_frame = pd.DataFrame(history.history)

history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot();
